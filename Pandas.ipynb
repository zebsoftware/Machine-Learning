# %% [markdown]
# <a href="https://colab.research.google.com/github/zebsoftware/Machine-Learning/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
country = ["pakistan",'india','nepal']
pd.Series(country)
# Out:
# 0    pakistan
# 1       india
# 2       nepal
# dtype: object

# %%
marks =[31,45,87,78]
pd.Series(marks)
# Out:
# 0    31
# 1    45
# 2    87
# 3    78
# dtype: int64

# %%
subjects = ['maths','english', 'physics','urdu']
pd.Series(marks,index=subjects)
print(marks)
# Out:
# [31, 45, 87, 78]

# %%
pd.Series(marks,index=subjects,name="my marks")
marks_series=pd.Series(marks,index=subjects,name="my marks")

# %%
marks_dict={
    'maths':31,
    'english':45,
    'physics':87,
    'urdu':78
}
marks_dict = pd.Series(marks_dict,name="ANWAR MARKS")

# %%
marks = pd.Series(marks)
marks.size
# Out:
# 4

# %%
marks.dtype
# Out:
# dtype('int64')

# %%
marks_dict.name
# Out:
# 'ANWAR MARKS'

# %%
marks.is_unique
# Out:
# True

# %%
marks.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
marks_series.values
# Out:
# array([31, 45, 87, 78])

# %%
from numpy._core.fromnumeric import squeeze
import pandas as pd
import numpy as np
type(pd.read_csv('/content/ember_features.csv').squeeze("columns"))


series=pd.read_csv('/content/ember_features.csv').squeeze("columns")
series
# Out:
#           size    vsize  imports  exports  has_debug  has_relocations  \
# 0      3101705   380928      156        0          0                0
# 1       504320   524288      619        0          1                0
# 2       180224   180224      273        0          1                1
# 3      2377730    77824        8        0          0                0
# 4      1153808  1167360      124        0          1                0
# ...        ...      ...      ...      ...        ...              ...
# 50107   311296   323584        7        0          0                0
# 50108  2125824  2936832     1695       18          1                0
# 50109   722048   722048       11        0          1                1
# 50110   521032   516096        0        1          1                1
# 50111  2260992  2371584        7        0          0                0
#
#        has_resources  has_signature  has_tls  symbols  ...  \
# 0                  1              0        0        0  ...
# ...
