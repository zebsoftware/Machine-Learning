# %% [markdown]
# <a href="https://colab.research.google.com/github/zebsoftware/Machine-Learning/blob/main/CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch as pyt
import torch.nn as nn
import torch.nn.functional as f

# %%
class TestNetwork(nn.Module):
    def __init__(self):
        super(TestNetwork, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=6, kernel_size=5)
        self.conv2 = nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv3 = nn.Conv2d(in_channels=16, out_channels=120, kernel_size=5)
    def forward(self, x):
        x = f.relu(self.conv1(x))
        x = self.f.relu(self.conv2(x))
        x = f.relu(self.conv3(x))
        print(x.shape)
        return x
